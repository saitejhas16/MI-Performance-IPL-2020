# %% [markdown]
# ### STATS AND PERFORMANCE OF MUMBAI INDIANS IN IPL 2020

# %%
#importing pandas,matplotlib and numpy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
path=r"C:\Users\SAI\OneDrive\Desktop\Ipl_2020.xlsx"
df=pd.read_excel(path)
#viewing top 5 rows of the data
df.head(5)
# Out:
#    Match No       Match                                       Match Center  \
# 0         1   MI vs CSK   Mumbai Indians (MI) Vs Chennai Super Kings (CSK)
# 1         2  DC vs KXIP      Delhi Capitals (DC) Vs Kings XI Punjab (KXIP)
# 2         3  SRH vs RCB  Sun Risers Hyderabad (SRH) Vs Royal Challenger...
# 3         4   RR vs CSK  Rajasthan Royals (RR) Vs Chennai Super Kings (...
# 4         5   KKR vs MI  Kolkata Knight Riders (KKR) Vs Mumbai Indians ...
#
#         Date        Day Time India (IST)     Time UAE      Venue Team-1  \
# 0 2020-09-19   Saturday      7:30 PM IST  6:00 PM UAE  Abu Dhabi     MI
# 1 2020-09-20     Sunday      7:30 PM IST  6:00 PM UAE      Dubai     DC
# 2 2020-09-21     Monday      7:30 PM IST  6:00 PM UAE      Dubai    SRH
# 3 2020-09-22    Tuesday      7:30 PM IST  6:00 PM UAE    Sharjah     RR
# 4 2020-09-23  Wednesday      7:30 PM IST  6:00 PM UAE  Abu Dhabi    KKR
#
#   Team-2 Toss Winner Toss Decision  dl_applied winner  win_by_wickets  \
# 0    CSK         CSK         Field           0    CSK               5
# 1   KXIP        KXIP         Field           0     DC               0
# 2    RCB         SRH         Field           0    RCB               0
# 3    CSK         CSK         Field           0     RR               0
# 4     MI         KKR         Field           0     MI               0
#
#    win_by_runs player_of_the_match  Result  Super Over
# 0            0       Ambati Rayudu  normal           0
# 1            0      Marcus Stoinis     Tie           1
# 2           10    Yuzvendra Chahal  normal           0
# 3           16        Sanju Samson  normal           0
# 4           49        Rohit Sharma  normal           0

# %%
##viewing the columns
df.columns
# Out:
# Index(['Match No', 'Match', 'Match Center', 'Date', 'Day', 'Time India (IST)',
#        'Time UAE', 'Venue', 'Team-1', 'Team-2', 'Toss Winner', 'Toss Decision',
#        'dl_applied', 'winner', 'win_by_wickets', 'win_by_runs',
#        'player_of_the_match', 'Result', 'Super Over'],
#       dtype='object')

# %%
##removing unwanted columns and creating a data set
cols=[2,4,6,8,9,12,14,15,16,18]
df_mod=df.drop(columns=[df.columns[i] for i in cols])
df_mod.head()
# Out:
#    Match No       Match       Date Time India (IST)      Venue Toss Winner  \
# 0         1   MI vs CSK 2020-09-19      7:30 PM IST  Abu Dhabi         CSK
# 1         2  DC vs KXIP 2020-09-20      7:30 PM IST      Dubai        KXIP
# 2         3  SRH vs RCB 2020-09-21      7:30 PM IST      Dubai         SRH
# 3         4   RR vs CSK 2020-09-22      7:30 PM IST    Sharjah         CSK
# 4         5   KKR vs MI 2020-09-23      7:30 PM IST  Abu Dhabi         KKR
#
#   Toss Decision winner  Result
# 0         Field    CSK  normal
# 1         Field     DC     Tie
# 2         Field    RCB  normal
# 3         Field     RR  normal
# 4         Field     MI  normal

# %%
##filtering only MI matches from the data
df_mi=df_mod[df_mod['Match'].str.contains('MI')]
df_mi
# Out:
#     Match No       Match       Date Time India (IST)      Venue Toss Winner  \
# 0          1   MI vs CSK 2020-09-19      7:30 PM IST  Abu Dhabi         CSK
# 4          5   KKR vs MI 2020-09-23      7:30 PM IST  Abu Dhabi         KKR
# 9         10   RCB vs MI 2020-09-28      7:30 PM IST      Dubai          MI
# 12        13  KXIP vs MI 2020-10-01      7:30 PM IST  Abu Dhabi        KXIP
# 16        17   MI vs SRH 2020-10-04      3:30 PM IST    Sharjah          MI
# 19        20    MI vs RR 2020-10-06      7:30 PM IST  Abu Dhabi          MI
# 26        27    MI vs DC 2020-10-11      7:30 PM IST  Abu Dhabi          DC
# 31        32   MI vs KKR 2020-10-16      7:30 PM IST  Abu Dhabi         KKR
# 35        36  MI vs KXIP 2020-10-18      7:30 PM IST      Dubai          MI
# 40        41   CSK vs MI 2020-10-23      7:30 PM IST    Sharjah          MI
# 44        45    RR vs MI 2020-10-25      7:30 PM IST  Abu Dhabi          MI
# 47        48   MI vs RCB 2020-10-28      7:30 PM IST  Abu Dhabi          MI
# 50        51    DC vs MI 2020-10-31      3:30 PM IST      Dubai          MI
# 55        56   SRH vs MI 2020-11-03      7:30 PM IST    Sharjah         SRH
# 56        57    MI vs DC 2020-11-05      7:30 PM IST      Dubai          DC
# 59        60    DC vs MI 2020-11-10      7:30 PM IST      Dubai          DC
#
#    Toss Decision winner  Result
# 0          Field    CSK  normal
# 4          Field     MI  normal
# 9          Field    RCB     Tie
# 12         Field     MI  normal
# 16           Bat     MI  normal
# 19           Bat     MI  normal
# 26           Bat     MI  normal
# 31           Bat     MI  normal
# 35           Bat   KXIP     Tie
# 40         Field     MI  normal
# 44           Bat     RR  normal
# 47         Field     MI  normal
# 50         Field     MI  normal
# 55         Field    SRH  normal
# 56         Field     MI  normal
# 59           Bat     MI  normal

# %%
df_mi.loc[:, 'Result'] = np.where(df_mi['winner'] == 'MI', 'Won', 'Lost')
df_mi
# Out:
#     Match No       Match        Date Time India (IST)      Venue Toss Winner  \
# 0          1   MI vs CSK  19-09-2020      7:30 PM IST  Abu Dhabi         CSK
# 4          5   KKR vs MI  23-09-2020      7:30 PM IST  Abu Dhabi         KKR
# 9         10   RCB vs MI  28-09-2020      7:30 PM IST      Dubai          MI
# 12        13  KXIP vs MI  01-10-2020      7:30 PM IST  Abu Dhabi        KXIP
# 16        17   MI vs SRH  04-10-2020      3:30 PM IST    Sharjah          MI
# 19        20    MI vs RR  06-10-2020      7:30 PM IST  Abu Dhabi          MI
# 26        27    MI vs DC  11-10-2020      7:30 PM IST  Abu Dhabi          DC
# 31        32   MI vs KKR  16-10-2020      7:30 PM IST  Abu Dhabi         KKR
# 35        36  MI vs KXIP  18-10-2020      7:30 PM IST      Dubai          MI
# 40        41   CSK vs MI  23-10-2020      7:30 PM IST    Sharjah          MI
# 44        45    RR vs MI  25-10-2020      7:30 PM IST  Abu Dhabi          MI
# 47        48   MI vs RCB  28-10-2020      7:30 PM IST  Abu Dhabi          MI
# 50        51    DC vs MI  31-10-2020      3:30 PM IST      Dubai          MI
# 55        56   SRH vs MI  03-11-2020      7:30 PM IST    Sharjah         SRH
# 56        57    MI vs DC  05-11-2020      7:30 PM IST      Dubai          DC
# 59        60    DC vs MI  10-11-2020      7:30 PM IST      Dubai          DC
#
#    Toss Decision winner Result
# 0          Field    CSK   Lost
# 4          Field     MI    Won
# 9          Field    RCB   Lost
# 12         Field     MI    Won
# 16           Bat     MI    Won
# 19           Bat     MI    Won
# 26           Bat     MI    Won
# 31           Bat     MI    Won
# 35           Bat   KXIP   Lost
# 40         Field     MI    Won
# 44           Bat     RR   Lost
# 47         Field     MI    Won
# 50         Field     MI    Won
# 55         Field    SRH   Lost
# 56         Field     MI    Won
# 59           Bat     MI    Won

# %%
#lets remove date and time column
df_mi=df_mi.drop(columns=['Date','Time India (IST)'])
df_mi
# Out:
#     Match No       Match      Venue Toss Winner Toss Decision winner Result
# 0          1   MI vs CSK  Abu Dhabi         CSK         Field    CSK   Lost
# 4          5   KKR vs MI  Abu Dhabi         KKR         Field     MI    Won
# 9         10   RCB vs MI      Dubai          MI         Field    RCB   Lost
# 12        13  KXIP vs MI  Abu Dhabi        KXIP         Field     MI    Won
# 16        17   MI vs SRH    Sharjah          MI           Bat     MI    Won
# 19        20    MI vs RR  Abu Dhabi          MI           Bat     MI    Won
# 26        27    MI vs DC  Abu Dhabi          DC           Bat     MI    Won
# 31        32   MI vs KKR  Abu Dhabi         KKR           Bat     MI    Won
# 35        36  MI vs KXIP      Dubai          MI           Bat   KXIP   Lost
# 40        41   CSK vs MI    Sharjah          MI         Field     MI    Won
# 44        45    RR vs MI  Abu Dhabi          MI           Bat     RR   Lost
# 47        48   MI vs RCB  Abu Dhabi          MI         Field     MI    Won
# 50        51    DC vs MI      Dubai          MI         Field     MI    Won
# 55        56   SRH vs MI    Sharjah         SRH         Field    SRH   Lost
# 56        57    MI vs DC      Dubai          DC         Field     MI    Won
# 59        60    DC vs MI      Dubai          DC           Bat     MI    Won

# %% [markdown]
# ## PIE CHART FOR NUMBER OF MATCHES WON VS LOST BY MI

# %%
# Calculate count of results
result_counts = df_mi['Result'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(6,4))
result_counts.plot(kind='pie', autopct='%1.1f%%', colors=['red', 'green'])
plt.title('Proportion of Matches Won and Lost')
plt.show()

# %% [markdown]
# ## Bar Plot by Venue: Count of Wins and Losses by Venue

# %%
# Count of wins and losses by venue
venue_result_counts = df_mi.groupby(['Venue', 'Result']).size().unstack().fillna(0)

# Plotting
venue_result_counts.plot(kind='bar', stacked=True, figsize=(6,5))
plt.title('Count of Matches Won and Lost by Venue')
plt.xlabel('Venue')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Result')
plt.show()
